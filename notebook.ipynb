# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
T = 1.0
n = 1000
dt = T / n
t = np.linspace(0, T, n)

dW = np.random.normal(0, np.sqrt(dt), n)

W = np.cumsum(dW)
W = np.insert(W, 0, 0)[:-1]

plt.plot(t, W)
plt.show()
